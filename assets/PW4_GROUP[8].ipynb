# %% [markdown]
# # Practical Work 4 - Genetic Algorithm (PW4_GROUP8)

# %% [markdown]
# ## Step 1 - Environment preparation

# %%
# %pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (2.2.5)
# Requirement already satisfied: pandas in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\gonza\desktop\pw4_ia2\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from typing import List
from abc import ABC, abstractmethod

# %% [markdown]
# ### Spanish Alphabet Setup

# %%
ALPHABET = list("ABCDEFGHIJKLMNÑOPQRSTUVWXYZ ")
CHAR_TO_IDX = {char: idx for idx, char in enumerate(ALPHABET)}
IDX_TO_CHAR = {idx: char for char, idx in CHAR_TO_IDX.items()}

# %% [markdown]
# ## Step 2 - Implementation

# %% [markdown]
# ### Fitness Function (In evaluate_fitness)

# %%
class Individual:
    def __init__(self, target: str):
        self.target = target
        self.target_len = len(target)
        # Store genes as indices
        self.genes = [random.randint(0, len(ALPHABET) - 1) for _ in range(self.target_len)]
        self.fitness = 0

    def __len__(self):
        return len(self.genes)

    def compute_fitness(self):
        # Convert target to indices for comparison
        target_indices = [CHAR_TO_IDX[c] for c in self.target]
        self.matches = sum(1 for g, t in zip(self.genes, target_indices) if g == t)
        self.fitness = np.exp(self.matches - self.target_len) - np.exp(-self.target_len)    #fitness function (Formula from instructions)
        return self.fitness

    def get_fitness(self):
        return self.fitness

    def set_genes(self, genes):
        self.genes = genes

    def __str__(self):
        return ''.join([IDX_TO_CHAR[i] for i in self.genes]) + f" : {self.fitness:.4f}"

    def flip_gene(self, position):
        self.genes[position] = random.randint(0, len(ALPHABET) - 1)


    def get_genes(self, start=None, end=None):
        return self.genes[start:end]

# %% [markdown]
# ### Selection Probability (In select)

# %%
class GeneticAlgorithm(ABC):
    def __init__(self, target, n, epochs, Pm, nres, nsam, elitism):
        self.target = target
        self.target_len = len(target)
        self.n = n
        self.epochs = epochs
        self.Pm = Pm
        self.nres = nres
        self.nsam = nsam
        self.elitism = elitism
        self.population = [Individual(target) for _ in range(n)]
        self.history = []
        elite_percentage = 0.05  # 5%
        self._elites = int(self.n * elite_percentage) if elitism else 0

        self._problem = target

    def init_population(self):
        for i in range(self.n):
            self.population[i] = Individual(self._problem)

    def print(self):
        for individual in self.population:
            print(individual)

    def compute_fitness(self):
        for individual in self.population:
            individual.compute_fitness()

    def set_population(self, population):
        self.population = population

    def get_best_individual(self):
        best = self.population[0]
        for i in range(1, len(self.population)):
            if best.get_fitness() < self.population[i].get_fitness():
                best = self.population[i]
        return best

    @abstractmethod
    def selection(self, size=100, elites=0):
        pass

    @abstractmethod
    def crossover(self, individual1, individual2):
        pass

    @abstractmethod
    def mutation(self, individual):
        pass

    def get_consensus(self):
        consensus = ""
        for i in range(self.target_len):
            freq = Counter(ind.genes[i] for ind in self.population)
            most_common = freq.most_common(1)[0][0]
            consensus += IDX_TO_CHAR[most_common]
        return consensus

    def select(self, threshold=0.4):
        max_fitness = max(ind.fitness for ind in self.population)
        selected = []
        for ind in self.population:
            ps = ind.fitness / max_fitness if max_fitness > 0 else 0      #Selection Probability (Formula from instructions)
            if ps > threshold:
                selected.append(ind)
        return selected

    def evolve(self, generations=100):
      for generation in range(generations):
          self.compute_fitness()
          best = self.get_best_individual()
          consensus = self.get_consensus()
          match_max = max(ind.matches for ind in self.population)
          match_avg = np.mean([ind.matches for ind in self.population])

          self.history.append([
              generation,
              best.get_fitness(),
              len(self.select(threshold=0.4)),
              (len(self.select(threshold=0.4)) / self.n) * 100,
              match_max,
              match_avg
          ])

          if generation % self.nres == 0:
              print(f"Generation {generation}:")
              print(f"  Best fitness: {best.get_fitness():.4f}")
              print(f"  Best individual: {best}")
              print(f"  Consensus: {consensus}")
              print(f"  MatchMax: {match_max}")
              print(f"  MatchAvg: {match_avg:.2f}")
              print(f"  BESTn: {len(self.select(threshold=0.4))}")
              print(f"  BEST%: {(len(self.select(threshold=0.4)) / self.n) * 100:.2f}%")

          elites_to_add = []
          if self._elites > 0:
              sorted_population = sorted(self.population, key=lambda ind: ind.get_fitness(), reverse=True)
              elites_to_add = [Individual(self.target) for _ in range(self._elites)]
              for i, elite in enumerate(sorted_population[:self._elites]):
                  elites_to_add[i].set_genes(elite.genes.copy())

              #  Apply mutation to elites as well
              for elite in elites_to_add:
                  self.mutation(elite)


          # Selection, crossover, mutation and replacement
          self.selection()

          # Replace the worst individuals with elites
          if self._elites > 0:
              self.population.sort(key=lambda ind: ind.get_fitness())
              self.population[:self._elites] = elites_to_add

          # Sampling step
          if generation % self.nsam == 0 and generation > 0:
              sample_size = int(0.2 * self.n)
              sampled_individuals = random.sample(self.population, sample_size)
              print(f"\nSampled Individuals at Generation {generation}:")
              for ind in sampled_individuals:
                  print(ind)

# %%
class MyGeneticAlgorithm(GeneticAlgorithm):

    def selection(self, size=100, elites=0):
        selected = self.select(threshold=0.4)
        for parent in selected:
            to_replace = random.choice(self.population)

            partner = random.choice(self.population)

            child = Individual(self.target)
            child.set_genes(self.crossover(parent, partner))

            # Mutate the child
            self.mutation(child)

            self.population[self.population.index(to_replace)] = child


        return self.population

    def crossover(self, individual1, individual2):
        crossover_point = random.randint(1, len(individual1))
        new_genes = individual1.get_genes(end=crossover_point) + individual2.get_genes(start=crossover_point)

        return new_genes

    def mutation(self, individual):
        for i in range(len(individual)):
            r = np.clip(np.random.normal(), 0, 1)
            if r > self.Pm:
                individual.genes[i] = random.randint(0, len(ALPHABET) - 1)

# %% [markdown]
# ## Step 3 - Execution

# %%
# Set up parameters
target = "ANIMULA VAGULA BLANDULA"

population_size = 1000
generations = 10000
Pm=0.8
nres=2
nsam=100

# Run with elitism
ga_elitism = MyGeneticAlgorithm(target, population_size, generations, Pm, nres, nsam, elitism=True)
ga_elitism.evolve(generations)
df_elitism = pd.DataFrame(ga_elitism.history, columns=["Epoch", "BESTf", "BESTn", "BEST%", "MatchMax", "MatchAvg"])

# Run without elitism
ga_no_elitism = MyGeneticAlgorithm(target, population_size, generations, Pm, nres, nsam, elitism=False)
ga_no_elitism.evolve(generations)
df_no_elitism = pd.DataFrame(ga_no_elitism.history, columns=["Epoch", "BESTf", "BESTn", "BEST%", "MatchMax", "MatchAvg"])

# Best individuals
print("Best individual with elitism:", ga_elitism.get_best_individual())
print("Best individual without elitism:", ga_no_elitism.get_best_individual())
# Out:
# Generation 0:
#   Best fitness: 0.0000
#   Best individual: JNOPJUA EQEMIR TLWKUC X : 0.0000
#   Consensus: PJ CZUMZBKLYHNAPRXUIUDQ
#   MatchMax: 5
#   MatchAvg: 0.84
#   BESTn: 2
#   BEST%: 0.20%
# Generation 2:
#   Best fitness: 0.0000
#   Best individual: JNOXJUA EQEMIR QLJKUC M : 0.0000
#   Consensus: ANIPUUMZBQFUHN BLAUUUDQ
#   MatchMax: 5
#   MatchAvg: 1.11
#   BESTn: 4
#   BEST%: 0.40%
# Generation 4:
#   Best fitness: 0.0000
#   Best individual: JNRXJ A EMEAIA QLJKSP M : 0.0000
#   Consensus: ANIPUTM VQGULA BLAUUULE
#   MatchMax: 6
#   MatchAvg: 1.45
#   BESTn: 2
#   BEST%: 0.20%
# Generation 6:
#   Best fitness: 0.0000
#   Best individual: JNOGUIA ÑTEMLR ÑLWDECGX : 0.0000
#   Consensus: ANOMUUM VQGULA BLAKUULF
#   MatchMax: 7
#   MatchAvg: 1.84
#   BESTn: 1
#   BEST%: 0.10%
# Generation 8:
#   Best fitness: 0.0000
#   Best individual: JNOGUIA ÑTEMLR ÑLWDECGX : 0.0000
#   Consensus: ANOMUUA VQGULA BLAKUULF
#   MatchMax: 7
#   MatchAvg: 2.27
#   BESTn: 1
#   BEST%: 0.10%
# Generation 10:
#   Best fitness: 0.0000
#   Best individual: ENHXYSA EMYTDA ZTZKDYLM : 0.0000
#   Consensus: ANOMUUA VIGULA BLAKUULF
#   MatchMax: 7
#   MatchAvg: 2.65
#   BESTn: 7
#   BEST%: 0.70%
# Generation 12:
#   Best fitness: 0.0000
#   Best individual: ZNIP UAAMXGIIKRBXWYURLA : 0.0000
#   Consensus: JNJMJUA VIGULA BLJKUU F
#   MatchMax: 7
#   MatchAvg: 3.01
#   BESTn: 16
#   BEST%: 1.60%
# Generation 14:
#   Best fitness: 0.0000
#   Best individual: JWIGUIA ÑPGFLY ELWPELKX : 0.0000
#   Consensus: JNOMIUA VIGJLA BLWKUU M
#   MatchMax: 8
#   MatchAvg: 3.35
#   BESTn: 1
#   BEST%: 0.10%
# Generation 16:
#   Best fitness: 0.0000
#   Best individual: ENHJKUA ESYAJA ZWWNDUJM : 0.0000
#   Consensus: JNOMIUA EMGJLA BLWKUULX
#   MatchMax: 8
#   MatchAvg: 3.77
#   BESTn: 3
#   BEST%: 0.30%
# Generation 18:
#   Best fitness: 0.0000
#   Best individual: ENHJKUA ESYAJA ZWWNDUJM : 0.0000
#   Consensus: JNOMUUA EMGALA BLWKUULX
#   MatchMax: 8
#   MatchAvg: 4.18
#   BESTn: 5
#   BEST%: 0.50%
# Generation 20:
#   Best fitness: 0.0000
#   Best individual: ENHJWUA FSYFWA ZLAYSUJM : 0.0000
#   Consensus: JNOMUUA EAGALA BLWKDULX
#   MatchMax: 8
#   MatchAvg: 4.54
#   BESTn: 8
#   BEST%: 0.80%
# Generation 22:
#   Best fitness: 0.0000
#   Best individual: APOGTYA LAGFLB ÑLHZÑFVX : 0.0000
#   Consensus: JNOMUUA EAGALA BLWKDULX
#   MatchMax: 8
#   MatchAvg: 4.86
#   BESTn: 11
#   BEST%: 1.10%
# Generation 24:
#   Best fitness: 0.0000
#   Best individual: ANHFÑKA ESYABA ZLBNUUJO : 0.0000
#   Consensus: JNOMUUA EAGALA BLWKDULX
#   MatchMax: 9
#   MatchAvg: 5.11
#   BESTn: 1
#   BEST%: 0.10%
# Generation 26:
#   Best fitness: 0.0000
#   Best individual: ANHFÑKA ESYABA ZLBNUUJO : 0.0000
#   Consensus: JNOMUUA EAGALA BLWKDULX
#   MatchMax: 9
#   MatchAvg: 5.41
#   BESTn: 1
#   BEST%: 0.10%
# Generation 28:
#   Best fitness: 0.0000
#   Best individual: ANHÑÑKA EIYZRA ZLBN UWO : 0.0000
#   Consensus: JNOMUUA EAGALA BLWKDULA
#   MatchMax: 9
#   MatchAvg: 5.67
#   BESTn: 4
#   BEST%: 0.40%
# Generation 30:
#   Best fitness: 0.0000
#   Best individual: ANHÑÑKA EIYZRA ZLBN UWO : 0.0000
#   Consensus: JNOMUUA EAGALA BLWNDULA
#   MatchMax: 9
#   MatchAvg: 5.91
#   BESTn: 4
#   BEST%: 0.40%
# Generation 32:
#   Best fitness: 0.0000
#   Best individual: RNZMUOACZAMGLATGTRYDCGA : 0.0000
#   Consensus: JNOMUUA EAGALA BLWNDULA
#   MatchMax: 9
#   MatchAvg: 6.11
#   BESTn: 8
#   BEST%: 0.80%
# Generation 34:
#   Best fitness: 0.0000
#   Best individual: ANHBÑKA EAYZVA YVBNLUWO : 0.0000
#   Consensus: JNHMUUA EAGALA BLBNDULA
#   MatchMax: 9
#   MatchAvg: 6.26
#   BESTn: 12
#   BEST%: 1.20%
# Generation 36:
#   Best fitness: 0.0000
#   Best individual: RNZMUCACZAGGLATPTRYDÑGA : 0.0000
#   Consensus: ANHMUUA EAGFLA BLBNDULA
#   MatchMax: 10
#   MatchAvg: 6.38
#   BESTn: 1
#   BEST%: 0.10%
# Generation 38:
#   Best fitness: 0.0000
#   Best individual: RNZMUCACZAGGLATPTRYDÑGA : 0.0000
#   Consensus: ANHMUUA EAGFLA BLBNDULA
#   MatchMax: 10
#   MatchAvg: 6.56
#   BESTn: 1
#   BEST%: 0.10%
# Generation 40:
#   Best fitness: 0.0000
#   Best individual: RIZTUSGMEATCLAHBLBDDULA : 0.0000
#   Consensus: ANHMUUA EAGFLA BLBNDUJA
#   MatchMax: 10
#   MatchAvg: 6.76
#   BESTn: 2
#   BEST%: 0.20%
# Generation 42:
#   Best fitness: 0.0000
#   Best individual: RNNMUCACZAGGLATPTRYDÑSA : 0.0000
#   Consensus: ANHMUSA EAGFLA BLBNDUJA
#   MatchMax: 10
#   MatchAvg: 6.92
#   BESTn: 4
#   BEST%: 0.40%
# Generation 44:
#   Best fitness: 0.0000
#   Best individual: ANÑMUYACZAGGLATLTWWDÑSA : 0.0000
#   Consensus: ANHMUSA EAGFLA BLBNDUJA
#   MatchMax: 11
#   MatchAvg: 7.08
#   BESTn: 1
#   BEST%: 0.10%
# Generation 46:
#   Best fitness: 0.0000
#   Best individual: ANÑMUYACZAGGLATLTWWDÑSA : 0.0000
#   Consensus: ANHMUSA EAGFLA BLBNDUJA
#   MatchMax: 11
#   MatchAvg: 7.21
#   BESTn: 1
#   BEST%: 0.10%
# Generation 48:
#   Best fitness: 0.0000
#   Best individual: ANÑMUYACZAGÑLATLTWWDZSA : 0.0000
#   Consensus: ANHMUSA EAGFLA BLBNDUJA
#   MatchMax: 11
#   MatchAvg: 7.36
#   BESTn: 2
#   BEST%: 0.20%
# Generation 50:
#   Best fitness: 0.0000
#   Best individual: ANIKÑUA CSGABA ZLBNUUEO : 0.0000
#   Consensus: ANHMUKA EAGGLA BLBNDUJA
#   MatchMax: 11
#   MatchAvg: 7.51
#   BESTn: 3
#   BEST%: 0.30%
# Generation 52:
#   Best fitness: 0.0000
#   Best individual: RNKMUNACNAGDLAZKTRCDUGA : 0.0000
#   Consensus: ANHMUKA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 7.65
#   BESTn: 4
#   BEST%: 0.40%
# Generation 54:
#   Best fitness: 0.0000
#   Best individual: RNKMUNACNAGDLAZKTRCDUGA : 0.0000
#   Consensus: ANHMUKA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 7.76
#   BESTn: 4
#   BEST%: 0.40%
# Generation 56:
#   Best fitness: 0.0000
#   Best individual: XNKMUNACQAGYLATBTRWPCLA : 0.0000
#   Consensus: ANHMUKA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 7.85
#   BESTn: 5
#   BEST%: 0.50%
# Generation 58:
#   Best fitness: 0.0000
#   Best individual: RAFTUL MVAPQLACBLBDDULK : 0.0000
#   Consensus: ANHMUYA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 7.99
#   BESTn: 10
#   BEST%: 1.00%
# Generation 60:
#   Best fitness: 0.0000
#   Best individual: ANIKÑUA MSGABA ZLBNUUKH : 0.0000
#   Consensus: ANHMUYA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.12
#   BESTn: 10
#   BEST%: 1.00%
# Generation 62:
#   Best fitness: 0.0000
#   Best individual: XNBMUFAOKAGTLAABTRWPCLA : 0.0000
#   Consensus: ANHMUYA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.22
#   BESTn: 11
#   BEST%: 1.10%
# Generation 64:
#   Best fitness: 0.0000
#   Best individual: ANIKÑUA ISGABA WLBNQUKH : 0.0000
#   Consensus: ANHMUYA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.32
#   BESTn: 12
#   BEST%: 1.20%
# Generation 66:
#   Best fitness: 0.0000
#   Best individual: ANYPULAXZAGLZACBTMLDQVA : 0.0000
#   Consensus: ANHMUYA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.40
#   BESTn: 14
#   BEST%: 1.40%
# Generation 68:
#   Best fitness: 0.0000
#   Best individual: ANIRÑUA COGABA WLJNQUKH : 0.0000
#   Consensus: ANKMUYA EAGGLA BLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.53
#   BESTn: 16
#   BEST%: 1.60%
# Generation 70:
#   Best fitness: 0.0000
#   Best individual: XNBMUWAQKAGYLASBTRTZCLA : 0.0000
#   Consensus: ANKMUYA ZAGGLATBTBWDULA
#   MatchMax: 11
#   MatchAvg: 8.61
#   BESTn: 19
#   BEST%: 1.90%
# Generation 72:
#   Best fitness: 0.0000
#   Best individual: ANIRÑUA ZOGABA WLJNQUKH : 0.0000
#   Consensus: ANKMUYA ZAGGLATBTBWDULA
#   MatchMax: 11
#   MatchAvg: 8.67
#   BESTn: 21
#   BEST%: 2.10%
# Generation 74:
#   Best fitness: 0.0000
#   Best individual:  NIÑ BA TFGABA Z ANDUEX : 0.0000
#   Consensus: ANIMUYA ZAGGLATBTBWDULA
#   MatchMax: 11
#   MatchAvg: 8.71
#   BESTn: 21
#   BEST%: 2.10%
# Generation 76:
#   Best fitness: 0.0000
#   Best individual: XIBMUSA YAGYLASBTROZSLA : 0.0000
#   Consensus: ANIMUYA ZAGGLATBTBWDULA
#   MatchMax: 11
#   MatchAvg: 8.74
#   BESTn: 24
#   BEST%: 2.40%
# Generation 78:
#   Best fitness: 0.0000
#   Best individual: ANÑMUCACZAGGLATLTWWDÑSA : 0.0000
#   Consensus: ANIMUYA ZAGGLATBLBWDULA
#   MatchMax: 11
#   MatchAvg: 8.77
#   BESTn: 25
#   BEST%: 2.50%
# Generation 80:
#   Best fitness: 0.0000
#   Best individual: ANÑMUCMCZAGGLATLTWWDÑLA : 0.0000
#   Consensus: ANIMUYA ZAGGLATBLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.86
#   BESTn: 38
#   BEST%: 3.80%
# Generation 82:
#   Best fitness: 0.0000
#   Best individual: ANIMTAA VAGXLMTFTGLWAYA : 0.0000
#   Consensus: ANIMUYA ZAGGLATBLBNDULA
#   MatchMax: 11
#   MatchAvg: 8.86
#   BESTn: 44
#   BEST%: 4.40%
# Generation 84:
#   Best fitness: 0.0000
#   Best individual: ANÑMUCACZAGULAÑLTWWDÑSA : 0.0000
#   Consensus: ANIMUYA ZAGGLATBLBNDULA
#   MatchMax: 12
#   MatchAvg: 8.93
#   BESTn: 2
#   BEST%: 0.20%
# Generation 86:
#   Best fitness: 0.0000
#   Best individual: ANYMUNACQAGFLAYBTRÑPCLA : 0.0000
#   Consensus: ANIMUYA ZAGGLA BLBNDULA
#   MatchMax: 12
#   MatchAvg: 9.05
#   BESTn: 4
#   BEST%: 0.40%
# Generation 88:
#   Best fitness: 0.0000
#   Best individual: RLFTULQ VAPCGANBLBSDULA : 0.0000
#   Consensus: ANIMUBA ZAGALA BLBNDULA
#   MatchMax: 12
#   MatchAvg: 9.18
#   BESTn: 6
#   BEST%: 0.60%
# Generation 90:
#   Best fitness: 0.0000
#   Best individual: RLFTULQ VAPCGANBLBSDULA : 0.0000
#   Consensus: ANIMUBA ZAGALA BLBNDULA
#   MatchMax: 12
#   MatchAvg: 9.28
#   BESTn: 6
#   BEST%: 0.60%
# Generation 92:
#   Best fitness: 0.0000
#   Best individual: RNBMUPAMVOGULAFHLBWDNSA : 0.0000
#   Consensus: ANIMUBA ZAGULATBLBNDULA
#   MatchMax: 12
#   MatchAvg: 9.40
#   BESTn: 11
#   BEST%: 1.10%
# Generation 94:
#   Best fitness: 0.0000
#   Best individual: RNBMUZAMVOGULAYGLBWDBSA : 0.0000
#   Consensus: ANIMUBA ZAGULATBLBWDULA
#   MatchMax: 12
#   MatchAvg: 9.50
#   BESTn: 14
#   BEST%: 1.40%
# Generation 96:
#   Best fitness: 0.0000
#   Best individual: ANIMTYAVVAGXLMTBTGODÑYA : 0.0000
#   Consensus: ANIMUBA ZAGULATBTBWDULA
#   MatchMax: 12
#   MatchAvg: 9.57
#   BESTn: 16
#   BEST%: 1.60%
# Generation 98:
#   Best fitness: 0.0000
#   Best individual:  LILTBA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA ZAGULATBTBWDULA
#   MatchMax: 13
#   MatchAvg: 9.62
#   BESTn: 1
#   BEST%: 0.10%
# Generation 100:
#   Best fitness: 0.0000
#   Best individual:  LILTBA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA ZAGULATBTBWDULA
#   MatchMax: 13
#   MatchAvg: 9.69
#   BESTn: 1
#   BEST%: 0.10%
#
# Sampled Individuals at Generation 100:
# AMRMGTAWXAGULMTKYAWDVSA : 0.0000
# AJDMUBAWZAGULATKNEWDÑSA : 0.0000
# XNBMUGAOKPGTLHLBTRWPSLA : 0.0000
# XNKMUNACQAIYLATBTRWPLLA : 0.0000
# YAFYUTULVAPGLASBLJDDNLH : 0.0000
# RLHQULUMEAPVLANBLÑSDUZA : 0.0000
# ANIMTYAVVAGXLMUXTGLDÑYJ : 0.0000
# AMU UBALZAXULATKYEWDASA : 0.0000
# ANQUUYAIBAGGXATATMWDQEA : 0.0000
# AVÑMUYACZAGGLATLFWBDÑSA : 0.0000
# XNBMUQAPKAGRÑATBTRJACLA : 0.0000
# RI TUJTMEALMLAZBWBLDULA : 0.0000
# ANÑMHYACZA GLATLTVWDÑMA : 0.0000
# YNIRDUA CUGABA WLJMQUHH : 0.0000
# RAFTUD MVAPQLACBLBDDOLK : 0.0000
# AMFMUYACZAGGSADLTWWDÑWA : 0.0000
# AUHFÑWA ESQUGAF LANLUHO : 0.0000
# ANIÑ BADTFGABV ZRAÑDUEX : 0.0000
# ANHAQKA KADZVA EGLNBUWU : 0.0000
# RLFT LQMEABVLANBQBYDULA : 0.0000
# LLMKULQMEAPVLAIBLBODÑLA : 0.0000
# ANXMHNVACÑGXLATLÑWFDUSA : 0.0000
# MWFTFLQ VAPCGAÑBLÑKDULD : 0.0000
# ANÑMUYACZWGFKATLT WDÑSA : 0.0000
# RNZMUOACZAMGLATPTRYDCVA : 0.0000
# RLFTULQ VAPCGANBBBCQNLA : 0.0000
# ANQTUGAIZAGGLATLTMWDÑEA : 0.0000
# ZDÑWUP MOAZWBACBLQADULA : 0.0000
# ANYMULACQLGFNAYBTRÑPCLA : 0.0000
# XNBMUTAULPGTLAABGRWPOLO : 0.0000
# ANDMPLACVAGGZETLTHRDÑBA : 0.0000
# ANÑMUYAWZAGGLAHMCRWÑPSQ : 0.0000
# ANKMUD CQAGYLATASRWFCLU : 0.0000
# UNIPNLA BHGAKV GHANEUEZ : 0.0000
# ANVKÑUA CSGABA LLBJUUEO : 0.0000
# FWYEULA RCXFDA GLNAEUYA : 0.0000
# AXHFÑWA ESQUGZ  LANLUUO : 0.0000
#  LJLUDA RARZLA M ANMUEG : 0.0000
#  DGL BA TVGALA ZFANDUEP : 0.0000
# ANYMENHJQAGUGUYBXAÑIELA : 0.0000
# QNIRÑUA ZOGABA DLJNKYKH : 0.0000
# RNKMURZIUAGHLADHTPWDMWA : 0.0000
# AJDWUBAWZAGULATDNEWDÑ A : 0.0000
# AMHMUBUWTAGULATKSAWDÑSI : 0.0000
# YNIC SA TCGABA Z ANDUXX : 0.0000
BA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA ZAGULATBTBWDULA
#   MatchMax: 13
#   MatchAvg: 9.74
#   BESTn: 1
#   BEST%: 0.10%
# Generation 104:
#   Best fitness: 0.0000
#   Best individual: ANUMTYAVVAGXLMTBZINDVLA : 0.0000
#   Consensus: ANIMUBA VAGULATBLBWDULA
#   MatchMax: 13
#   MatchAvg: 9.82
#   BESTn: 2
#   BEST%: 0.20%
# Generation 106:
#   Best fitness: 0.0000
#   Best individual: ANDMUBAWVAGULXYKERNDJEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLBWDULA
#   MatchMax: 13
#   MatchAvg: 9.88
#   BESTn: 3
#   BEST%: 0.30%
# Generation 108:
#   Best fitness: 0.0000
#   Best individual: ANDMUBAWVAGULXYKERNDJEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLAWDULA
#   MatchMax: 13
#   MatchAvg: 9.95
#   BESTn: 3
#   BEST%: 0.30%
# Generation 110:
#   Best fitness: 0.0000
#   Best individual: ANDMUBAWVAGULXYKERNDJEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 13
#   MatchAvg: 10.02
#   BESTn: 3
#   BEST%: 0.30%
# Generation 112:
#   Best fitness: 0.0000
#   Best individual: ANDMUBAWVAGULXYKERNDJEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 13
#   MatchAvg: 10.12
#   BESTn: 3
#   BEST%: 0.30%
# Generation 114:
#   Best fitness: 0.0000
#   Best individual:  DIJTBA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 13
#   MatchAvg: 10.20
#   BESTn: 4
#   BEST%: 0.40%
# Generation 116:
#   Best fitness: 0.0000
#   Best individual:  DIJTBA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 13
#   MatchAvg: 10.29
#   BESTn: 4
#   BEST%: 0.40%
# Generation 118:
#   Best fitness: 0.0000
#   Best individual:  DIJTBA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLANDÑLA
#   MatchMax: 13
#   MatchAvg: 10.38
#   BESTn: 4
#   BEST%: 0.40%
# Generation 120:
#   Best fitness: 0.0000
#   Best individual:  DIJTBA PAGZLA Y ANDUEA : 0.0000
#   Consensus: ANIMUBA VAGULATBLANDÑLA
#   MatchMax: 13
#   MatchAvg: 10.44
#   BESTn: 4
#   BEST%: 0.40%
# Generation 122:
#   Best fitness: 0.0001
#   Best individual:  NILTLA PAGYLA Y ANDUEQ : 0.0001
#   Consensus: ANIMUBA VAGULATBLANDÑLA
#   MatchMax: 14
#   MatchAvg: 10.48
#   BESTn: 1
#   BEST%: 0.10%
# Generation 124:
#   Best fitness: 0.0001
#   Best individual:  NILTLA PAGYLA Y ANDUEQ : 0.0001
#   Consensus: ANIMUBA VAGULATBLANDÑLA
#   MatchMax: 14
#   MatchAvg: 10.54
#   BESTn: 1
#   BEST%: 0.10%
# Generation 126:
#   Best fitness: 0.0001
#   Best individual: ANYMENQ QAGURAABLARIULA : 0.0001
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 14
#   MatchAvg: 10.57
#   BESTn: 2
#   BEST%: 0.20%
# Generation 128:
#   Best fitness: 0.0001
#   Best individual: ANYMENQ QAGURAABLARIULA : 0.0001
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 14
#   MatchAvg: 10.63
#   BESTn: 2
#   BEST%: 0.20%
# Generation 130:
#   Best fitness: 0.0001
#   Best individual: YNYMENQ QAGULAABLARIULA : 0.0001
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 14
#   MatchAvg: 10.68
#   BESTn: 3
#   BEST%: 0.30%
# Generation 132:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULATBLANDULA
#   MatchMax: 15
#   MatchAvg: 10.75
#   BESTn: 1
#   BEST%: 0.10%
# Generation 134:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 10.81
#   BESTn: 1
#   BEST%: 0.10%
# Generation 136:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 10.87
#   BESTn: 1
#   BEST%: 0.10%
# Generation 138:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 10.97
#   BESTn: 1
#   BEST%: 0.10%
# Generation 140:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.07
#   BESTn: 1
#   BEST%: 0.10%
# Generation 142:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.15
#   BESTn: 1
#   BEST%: 0.10%
# Generation 144:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUBA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.26
#   BESTn: 1
#   BEST%: 0.10%
# Generation 146:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.35
#   BESTn: 1
#   BEST%: 0.10%
# Generation 148:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMTNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.43
#   BESTn: 1
#   BEST%: 0.10%
# Generation 150:
#   Best fitness: 0.0003
#   Best individual: RNIMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMUNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.49
#   BESTn: 1
#   BEST%: 0.10%
# Generation 152:
#   Best fitness: 0.0003
#   Best individual: ANVMKLV VAGUCAIBLAATYLA : 0.0003
#   Consensus: ANIMUNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.53
#   BESTn: 2
#   BEST%: 0.20%
# Generation 154:
#   Best fitness: 0.0003
#   Best individual: ANVMKLV VAGUCAIBLAATYLA : 0.0003
#   Consensus: ANIMTNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.60
#   BESTn: 2
#   BEST%: 0.20%
# Generation 156:
#   Best fitness: 0.0003
#   Best individual: ANVMKLV VAGUCAIBLAATYLA : 0.0003
#   Consensus: ANIMUNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.65
#   BESTn: 2
#   BEST%: 0.20%
# Generation 158:
#   Best fitness: 0.0003
#   Best individual: ANIMERA VAYXLDRBLATEULA : 0.0003
#   Consensus: ANIMUNA VAGULA BLANDULA
#   MatchMax: 15
#   MatchAvg: 11.70
#   BESTn: 3
#   BEST%: 0.30%
# Generation 160:
#   Best fitness: 0.0003
#   Best individual: ANIMERA VAYXLDRBLATEULA : 0.0003
#   Consensus: ANIMENA QAGULAABLANDULA
#   MatchMax: 15
#   MatchAvg: 11.77
#   BESTn: 3
#   BEST%: 0.30%
# Generation 162:
#   Best fitness: 0.0003
#   Best individual: ANIMERA VAYXLDRBLATEULA : 0.0003
#   Consensus: ANIMENA QAGULAABLANDULA
#   MatchMax: 15
#   MatchAvg: 11.84
#   BESTn: 3
#   BEST%: 0.30%
# Generation 164:
#   Best fitness: 0.0003
#   Best individual: ANIMERA VAYXLDRBLATEULA : 0.0003
#   Consensus: ANIMENA QAGULAABLANDULA
#   MatchMax: 15
#   MatchAvg: 11.89
#   BESTn: 3
#   BEST%: 0.30%
# Generation 166:
#   Best fitness: 0.0003
#   Best individual: ANKMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMENA QAGULAABLANDULA
#   MatchMax: 15
#   MatchAvg: 11.97
#   BESTn: 4
#   BEST%: 0.40%
# Generation 168:
#   Best fitness: 0.0003
#   Best individual: ANYMENQ YAGULAABLARIULA : 0.0003
#   Consensus: ANIMENA QAGULAABLANDULA
#   MatchMax: 15
#   MatchAvg: 12.04
#   BESTn: 5
#   BEST%: 0.50%
# Generation 170:
#   Best fitness: 0.0003
#   Best individual: NNIMENI SAYULAIBLAJDULA : 0.0003
#   Consensus: ANIMENA QAGULAABLARDULA
#   MatchMax: 15
#   MatchAvg: 12.09
#   BESTn: 6
#   BEST%: 0.60%
# Generation 172:
#   Best fitness: 0.0003
#   Best individual: NNIMENI SAYULAIBLAIDULA : 0.0003
#   Consensus: ANIMENA QAGULAABLARIULA
#   MatchMax: 15
#   MatchAvg: 12.16
#   BESTn: 9
#   BEST%: 0.90%
# Generation 174:
#   Best fitness: 0.0003
#   Best individual: ANIMETÑ QHGURAGBLANDUCA : 0.0003
#   Consensus: ANIMENA QAGULAABLARIULA
#   MatchMax: 15
#   MatchAvg: 12.22
#   BESTn: 10
#   BEST%: 1.00%
# Generation 176:
#   Best fitness: 0.0003
#   Best individual: ANIMETÑ QHGURAGBLANDUCA : 0.0003
#   Consensus: ANIMENA QAGULAABLARIULA
#   MatchMax: 15
#   MatchAvg: 12.28
#   BESTn: 10
#   BEST%: 1.00%
# Generation 178:
#   Best fitness: 0.0003
#   Best individual: ANIMWTÑ QHGURAGBLANDUCA : 0.0003
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 15
#   MatchAvg: 12.34
#   BESTn: 10
#   BEST%: 1.00%
# Generation 180:
#   Best fitness: 0.0003
#   Best individual: ANIMWTÑ QHGURAGBLANDUCA : 0.0003
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 15
#   MatchAvg: 12.41
#   BESTn: 10
#   BEST%: 1.00%
# Generation 182:
#   Best fitness: 0.0003
#   Best individual: ANKMENQ QAGULAABLARIULA : 0.0003
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 15
#   MatchAvg: 12.46
#   BESTn: 12
#   BEST%: 1.20%
# Generation 184:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.49
#   BESTn: 1
#   BEST%: 0.10%
# Generation 186:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.53
#   BESTn: 1
#   BEST%: 0.10%
# Generation 188:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.57
#   BESTn: 1
#   BEST%: 0.10%
# Generation 190:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.62
#   BESTn: 1
#   BEST%: 0.10%
# Generation 192:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.68
#   BESTn: 1
#   BEST%: 0.10%
# Generation 194:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.71
#   BESTn: 1
#   BEST%: 0.10%
# Generation 196:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.78
#   BESTn: 1
#   BEST%: 0.10%
# Generation 198:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.80
#   BESTn: 1
#   BEST%: 0.10%
# Generation 200:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.85
#   BESTn: 1
#   BEST%: 0.10%
#
# Sampled Individuals at Generation 200:
# AKIMVZA JAGXLDGBUAZEULA : 0.0000
# ANILQWV XAGUQAEBLADICLH : 0.0000
# ANYMENQ QAGURAABXAQICLA : 0.0000
# AYYBHNQ YAGULAABLARRULA : 0.0000
# ANIMTNR QAGULAAGLARIXLR : 0.0000
# ANHJ LZ YMGULUABGAAOULP : 0.0000
# ZNJMUPA ÑAGUNZXBLAGPELA : 0.0000
#  NKRTSA OAGYJA YLANDUYQ : 0.0000
# RN MUPACVOGULABJLCWMNLA : 0.0000
# ANIMEAN JAJXLZGBLAZEULA : 0.0000
# VDIJTFA PAGSLAEBDANDUWA : 0.0000
# ANIMEOA OAQXLDOBUAZEULA : 0.0000
# ANYMEFB IAGULAARLVRIULA : 0.0000
# ANZMENN QAGFLAABTAKWULA : 0.0000
#  LILTBA PAGZLA Y GNDUEA : 0.0000
# AJIMETM NHGUVOGBLANDUCA : 0.0000
# ANILERA JACXLDGBLAZIULA : 0.0000
# ANVQJLM VAGPEAIBLAUTYLA : 0.0000
# ANICGBÑ PZGURAXBLANDVCA : 0.0000
# ANYMENS KAGULAABCARQULA : 0.0001
# ANUMSSQ JAGUJAABLJUEULA : 0.0000
# ANIMWTÑ QSGUZAGBIANDURA : 0.0001
# ANJMCSQ UAGUYAZBLAOMULO : 0.0000
# VRIJTBA PAGZLAEB ANDUWA : 0.0000
# ANBMSSQ QAGZJAIULAWSULA : 0.0000
# ANIPEYU VAXXLDNBLAMEULA : 0.0000
# ANVMJLV VAGPQAIBLAVTYLA : 0.0001
# YNIMQNI SAYULAIBLAJDULA : 0.0003
# ANYMEÑQ QAGURAABLÑTIULA : 0.0000
# WNYMUNQ VAGUREZBIARUUVA : 0.0000
# LNILTLA VAPWLA YRANYUE  : 0.0000
# ANVMQCVESAGUQAABLAAI LA : 0.0000
# ANHMKLZ QMGULAABLAZIULA : 0.0003
# ANIMQWV XAGUQAFBLAAICLG : 0.0000
# ANKMENQ QAGULAGBLQRUVLA : 0.0000
# Generation 202:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.89
#   BESTn: 1
#   BEST%: 0.10%
# Generation 204:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.93
#   BESTn: 1
#   BEST%: 0.10%
# Generation 206:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 12.96
#   BESTn: 1
#   BEST%: 0.10%
# Generation 208:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.00
#   BESTn: 1
#   BEST%: 0.10%
# Generation 210:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.07
#   BESTn: 1
#   BEST%: 0.10%
# Generation 212:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 214:
#   Best fitness: 0.0009
#   Best individual: ANKMELZ QAGULAABLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.17
#   BESTn: 1
#   BEST%: 0.10%
# Generation 216:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.23
#   BESTn: 2
#   BEST%: 0.20%
# Generation 218:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.31
#   BESTn: 2
#   BEST%: 0.20%
# Generation 220:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.37
#   BESTn: 2
#   BEST%: 0.20%
# Generation 222:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.36
#   BESTn: 2
#   BEST%: 0.20%
# Generation 224:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.41
#   BESTn: 2
#   BEST%: 0.20%
# Generation 226:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.42
#   BESTn: 2
#   BEST%: 0.20%
# Generation 228:
#   Best fitness: 0.0009
#   Best individual: ANIMENI SAYULAIBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.42
#   BESTn: 2
#   BEST%: 0.20%
# Generation 230:
#   Best fitness: 0.0009
#   Best individual: ANYMENQ QAGULA BLARIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.47
#   BESTn: 3
#   BEST%: 0.30%
# Generation 232:
#   Best fitness: 0.0009
#   Best individual: ANIMESI SAYULASBLAJDULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.49
#   BESTn: 4
#   BEST%: 0.40%
# Generation 234:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.49
#   BESTn: 5
#   BEST%: 0.50%
# Generation 236:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.52
#   BESTn: 5
#   BEST%: 0.50%
# Generation 238:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.54
#   BESTn: 5
#   BEST%: 0.50%
# Generation 240:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.55
#   BESTn: 5
#   BEST%: 0.50%
# Generation 242:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.55
#   BESTn: 5
#   BEST%: 0.50%
# Generation 244:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIIULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.60
#   BESTn: 4
#   BEST%: 0.40%
# Generation 246:
#   Best fitness: 0.0009
#   Best individual: ANYMHLQ KAGULAABLAQQULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.60
#   BESTn: 5
#   BEST%: 0.50%
# Generation 248:
#   Best fitness: 0.0009
#   Best individual: ANYMHLQ KAGULAABLAQQULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.61
#   BESTn: 5
#   BEST%: 0.50%
# Generation 250:
#   Best fitness: 0.0009
#   Best individual: ANYMHLQ KAGULAABLAQQULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.63
#   BESTn: 5
#   BEST%: 0.50%
# Generation 252:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIOULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.64
#   BESTn: 6
#   BEST%: 0.60%
# Generation 254:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIOULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.64
#   BESTn: 6
#   BEST%: 0.60%
# Generation 256:
#   Best fitness: 0.0009
#   Best individual: ANYMENH QAGULA BLAIOULA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.67
#   BESTn: 6
#   BEST%: 0.60%
# Generation 258:
#   Best fitness: 0.0009
#   Best individual: ANIMLOA VAOULA BTAVWHLA : 0.0009
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 16
#   MatchAvg: 13.70
#   BESTn: 7
#   BEST%: 0.70%
# Generation 260:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLAMIULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.72
#   BESTn: 1
#   BEST%: 0.10%
# Generation 262:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLAMIULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.74
#   BESTn: 1
#   BEST%: 0.10%
# Generation 264:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLAMIULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.75
#   BESTn: 1
#   BEST%: 0.10%
# Generation 266:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.79
#   BESTn: 2
#   BEST%: 0.20%
# Generation 268:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.79
#   BESTn: 2
#   BEST%: 0.20%
# Generation 270:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.82
#   BESTn: 2
#   BEST%: 0.20%
# Generation 272:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.86
#   BESTn: 2
#   BEST%: 0.20%
# Generation 274:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.89
#   BESTn: 2
#   BEST%: 0.20%
# Generation 276:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.91
#   BESTn: 2
#   BEST%: 0.20%
# Generation 278:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.94
#   BESTn: 2
#   BEST%: 0.20%
# Generation 280:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUUA BLARLULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 13.96
#   BESTn: 2
#   BEST%: 0.20%
# Generation 282:
#   Best fitness: 0.0025
#   Best individual: ANIMUOA VAGULA DLAXWCSA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.01
#   BESTn: 3
#   BEST%: 0.30%
# Generation 284:
#   Best fitness: 0.0025
#   Best individual: ANIMUOA VAGULA DLAXWCSA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.00
#   BESTn: 3
#   BEST%: 0.30%
# Generation 286:
#   Best fitness: 0.0025
#   Best individual: ANIMUOA VAGULA DLAXWCSA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.06
#   BESTn: 3
#   BEST%: 0.30%
# Generation 288:
#   Best fitness: 0.0025
#   Best individual: ANIMUOA VAGULA DLAXWCSA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.07
#   BESTn: 3
#   BEST%: 0.30%
# Generation 290:
#   Best fitness: 0.0025
#   Best individual: ANYMUBH QAGULA BLAIBULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.11
#   BESTn: 4
#   BEST%: 0.40%
# Generation 292:
#   Best fitness: 0.0025
#   Best individual: ANYMUBH QAGULA BLAIBULA : 0.0025
#   Consensus: ANIMENQ QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.13
#   BESTn: 4
#   BEST%: 0.40%
# Generation 294:
#   Best fitness: 0.0025
#   Best individual: ANYMUBH QAGULA BLAIBULA : 0.0025
#   Consensus: ANIMELA QAGULAABLARIULA
#   MatchMax: 17
#   MatchAvg: 14.16
#   BESTn: 4
#   BEST%: 0.40%
# Generation 296:
#   Best fitness: 0.0025
#   Best individual: ANYMUBH QAGULA BLAIBULA : 0.0025
#   Consensus: ANIMELA QAGULA BLARIULA
#   MatchMax: 17
#   MatchAvg: 14.23
#   BESTn: 5
#   BEST%: 0.50%
# Generation 298:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUHA BLAMÑULA : 0.0025
#   Consensus: ANIMELA QAGULA BLARIULA
#   MatchMax: 17
#   MatchAvg: 14.22
#   BESTn: 6
#   BEST%: 0.60%
# Generation 300:
#   Best fitness: 0.0025
#   Best individual: ANKM LA QAGUHA BLAMÑULA : 0.0025
#   Consensus: ANIMELA QAGULA BLARIULA
#   MatchMax: 17
#   MatchAvg: 14.27
#   BESTn: 6
#   BEST%: 0.60%
#
# Sampled Individuals at Generation 300:
# ANIMEEJ SAYULAPBLÑJDUOA : 0.0001
# ANYMENHMZAGULA BJAPOULA : 0.0001
# ANIMFNY VAYSLDLBLATEULA : 0.0001
# ANHMHLK KAGULAZBLAFQHRA : 0.0001
# ANIMFGA VAKXLDRBLAVEULA : 0.0003
# ANYMHLX KAGULAABLAQGULA : 0.0009
# ANIMENI ÑDYYLANBLAJDULA : 0.0001
# ANIMLOA VAGUQA BTXNWHSO : 0.0001
# GNKMUAV ÑTGULATBLAVGULA : 0.0001
# ANYTENI TAGCLA BLACOULA : 0.0001
# ANIMSNC RAOURAIBLAVWULA : 0.0001
# ANYMINH YAGULA BLTIIUPA : 0.0001
# AKYMEVPLQAGULA BLARIULA : 0.0000
# ANYMVNQ QAGULA BBERIULA : 0.0001
# ANSMLHA ZAGULARCLANTUPV : 0.0001
# ANVMENH QAGULA BLWIIULX : 0.0001
# ANKMUPQ QSGULAABLARIUOA : 0.0001
# ANIMGSÑ IZGURAXB ANDUCA : 0.0001
# ANIMLOA VAGULA BTAXWHSP : 0.0003
# ANXMEVZ PAGULAFBLVRDULA : 0.0003
# ANYMXNH QAGULA BLAIQVLA : 0.0003
# ANKMOUQ QRGULB BLARZULA : 0.0001
# ANIMLOA VLOÑLA BTAVWHLA : 0.0001
# ANYMKLK VAGUGAIBLAPLYLA : 0.0003
# NNIMGNP SAYULAIBLAJDULA : 0.0003
# ANIMBLZCIMGULABBLAQIOLA : 0.0001
# ANYMENU QAGULAAVLARIULA : 0.0001
# ANIMEÑGHSAYULAIBLAJDYLA : 0.0001
# ANWMUIQ QSGULAABLATI LA : 0.0001
# ANRMUBH QAGULA BMAPBULA : 0.0009
# RNIMENQ QAGULALBLAVIUIA : 0.0001
# ...
#   BEST%: 0.10%
#
# Sampled Individuals at Generation 9900:
# AHUVCWAXMAMÑLM BTANÑUOD : 0.0000
# AÑINULA FAGYMMBBLÑXVÑOQ : 0.0000
# AHIXÑLA WHVULFJYGALTSUC : 0.0000
# ANWMILU VJGVLR BFBXFVOZ : 0.0000
# RNOBULA VAGULY BLBNDIIB : 0.0003
# JHIVCGA VAGULMJBLYGQDGT : 0.0000
# ANISULI VARULC ZLSNBTAQ : 0.0000
# ACIIUQA ELGG MÑBGYAÑUXI : 0.0000
# ANIMULA VAGULJ BLAXUBVQ : 0.0025
# ANIMNLNOSAGUL  RT IKBVQ : 0.0000
# ANIMULA VAGUYMYBLRFAQBQ : 0.0001
# ANYJURA VAGCFD BLAHTPEA : 0.0000
# AHIFCLA VAGULM BSAMYO H : 0.0000
# ANIVULA VAGRLHZKIHQQXWH : 0.0000
# ANPMNLA LAWUFLUBYPHTPEA : 0.0000
# ANWIULA VADKVOWHXENDN Y : 0.0000
# ADIVCLNÑVAIUAE TKCKYZ H : 0.0000
# ANUMCLXXIATALM BL MAKÑU : 0.0000
# AHIVILSNVAHNOVAIBÑMBFLC : 0.0000
# BNIMCLAKVQGULN BAAM ZVC : 0.0000
# TNIMNPA VAAULYÑ LYWJIHK : 0.0000
# ANTMULYZEAMWLOMMLSXXRFB : 0.0000
# AKGMULA VHJUÑB BLABTJZZ : 0.0000
# ANIXUJA VADULYUPLKMUFLC : 0.0000
# ANIVULA VOG LYSBLMPMTLL : 0.0000
# ANIVSLC BA GANQPGKEGSOX : 0.0000
# AHIVGLA VAGULM BYENZTLL : 0.0001
# AHIWÑLU VAGULX BLANWLYA : 0.0003
# XNIMULNTBHZUÑX VUNAHUXG : 0.0000
# AHIVOLA VNJULM BLWNDUZE : 0.0001
# ANMMNRA VUÑCLQ B UTEWYX : 0.0000
# ANIMNÑADVKGMZK  PKOORJV : 0.0000
# CNIXULA AAGUAYEB SDIPUX : 0.0000
# ANICULA IAG LCHZCFYVTOB : 0.0000
# ANIVSLSMVAJU YIBHPVJTK  : 0.0000
# ANREULUDNWGULTWLSANRJI  : 0.0000
# APCXULA VAGULR BJYCBFSS : 0.0000
# ANKXULA VAGUL OVLYADMZP : 0.0000
# Generation 9902:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9904:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9906:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9908:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9910:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9912:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9914:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9916:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9918:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9920:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9922:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9924:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9926:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9928:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9930:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9932:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9934:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9936:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9938:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9940:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9942:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9944:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9946:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9948:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9950:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9952:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9954:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9956:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9958:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9960:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIVULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9962:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.11
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9964:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.11
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9966:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9968:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9970:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9972:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9974:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9976:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9978:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.12
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9980:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9982:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9984:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.13
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9986:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9988:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9990:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9992:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9994:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9996:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.14
#   BESTn: 1
#   BEST%: 0.10%
# Generation 9998:
#   Best fitness: 0.0067
#   Best individual: ANIMNLA VAGULL BIANTUNA : 0.0067
#   Consensus: ANIMULA VAGULM BLANDUPA
#   MatchMax: 18
#   MatchAvg: 11.15
#   BESTn: 1
#   BEST%: 0.10%
# Best individual with elitism: ANIMULA VAGULA BLANDULA : 1.0000
# Best individual without elitism: ANIMNLA VAGULL BIANTUNA : 0.0067

# %% [markdown]
# ## Step 4 - Evaluation

# %%
def plot_results(df, title):
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df, x="Epoch", y="MatchMax", label="MatchMax")
    sns.lineplot(data=df, x="Epoch", y="MatchAvg", label="MatchAvg")
    sns.lineplot(data=df, x="Epoch", y="BEST%", label="BEST%")
    plt.title(title)
    plt.xlabel("Generation")
    plt.ylabel("Metric Value")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# plot metrics for both configurations
target_length = len(target)

print("Analyzing metrics for configuration WITH Elitism:")
plot_results(df_elitism, f"With Elitism (Target Length: {target_length}, Population: {population_size}, Generations: {generations})")

print("Analyzing metrics for configuration WITHOUT Elitism:")
plot_results(df_no_elitism, f"Without Elitism (Target Length: {target_length}, Population: {population_size}, Generations: {generations})")

print("\nComparison of Metrics:")
print("With Elitism:")
print(df_elitism.describe())
print("\nWithout Elitism:")
print(df_no_elitism.describe())
# Out:
# Analyzing metrics for configuration WITH Elitism:
# Analyzing metrics for configuration WITHOUT Elitism:
# Comparison of Metrics:
# With Elitism:
#              Epoch         BESTf         BESTn         BEST%      MatchMax  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    4999.50000  7.924162e-01      4.523200      0.452320     22.311500
# std     2886.89568  3.545782e-01      2.788914      0.278891      1.842337
# min        0.00000  1.512736e-08      1.000000      0.100000      5.000000
# 25%     2499.75000  3.678794e-01      2.000000      0.200000     22.000000
# 50%     4999.50000  1.000000e+00      4.000000      0.400000     23.000000
# 75%     7499.25000  1.000000e+00      7.000000      0.700000     23.000000
# max     9999.00000  1.000000e+00     44.000000      4.400000     23.000000
#
#            MatchAvg
# count  10000.000000
# mean      19.839369
# std        2.041391
# min        0.845000
# 25%       19.488000
# 50%       20.467000
# 75%       20.687000
# max       21.094000
#
# Without Elitism:
#              Epoch         BESTf         BESTn         BEST%      MatchMax  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    4999.50000  6.939550e-03      2.550600      0.255060     16.306700
# std     2886.89568  7.622979e-03      2.437136      0.243714      2.878518
# min        0.00000  4.129676e-08      1.000000      0.100000      6.000000
# 25%     2499.75000  3.354625e-04      1.000000      0.100000     15.000000
# 50%     4999.50000  2.478752e-03      2.000000      0.200000     17.000000
# 75%     7499.25000  1.831564e-02      3.000000      0.300000     19.000000
# max     9999.00000  1.831564e-02     18.000000      1.800000     19.000000
#
#            MatchAvg
# count  10000.000000
# mean       9.463085
# std        2.819722
# min        0.786000
# 25%        8.705500
# 50%       10.413000
# 75%       11.695000
# max       12.274000

# %%
color_elitism = "blue"
color_no_elitism = "orange"

# Plot BESTf vs Generations
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_no_elitism, x="Epoch", y="BESTf", label="BESTf (Without Elitism)", color=color_no_elitism)
sns.lineplot(data=df_elitism, x="Epoch", y="BESTf", label="BESTf (With Elitism)", color=color_elitism)
plt.title(f"BESTf vs Generations (Target Length: {target_length}, Population: {population_size})")
plt.xlabel("Generations")
plt.ylabel("BESTf")
plt.legend()
plt.grid(True)
plt.show()

# Plot MatchMax vs Generations
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_no_elitism, x="Epoch", y="MatchMax", label="MatchMax (Without Elitism)", color=color_no_elitism)
sns.lineplot(data=df_elitism, x="Epoch", y="MatchMax", label="MatchMax (With Elitism)", color=color_elitism)
plt.title(f"MatchMax vs Generations (Target Length: {target_length}, Population: {population_size})")
plt.xlabel("Generations")
plt.ylabel("MatchMax")
plt.legend()
plt.grid(True)
plt.show()

# Plot MatchAvg vs Generations
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_no_elitism, x="Epoch", y="MatchAvg", label="MatchAvg (Without Elitism)", color=color_no_elitism)
sns.lineplot(data=df_elitism, x="Epoch", y="MatchAvg", label="MatchAvg (With Elitism)", color=color_elitism)
plt.title(f"MatchAvg vs Generations (Target Length: {target_length}, Population: {population_size})")
plt.xlabel("Generations")
plt.ylabel("MatchAvg")
plt.legend()
plt.grid(True)
plt.show()

# Plot BEST% vs Generations
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_no_elitism, x="Epoch", y="BEST%", label="BEST% (Without Elitism)", color=color_no_elitism)
sns.lineplot(data=df_elitism, x="Epoch", y="BEST%", label="BEST% (With Elitism)", color=color_elitism)
plt.title(f"BEST% vs Generations (Target Length: {target_length}, Population: {population_size})")
plt.xlabel("Generations")
plt.ylabel("BEST%")
plt.legend()
plt.grid(True)
plt.show()

# Plot BESTn vs Generations
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_no_elitism, x="Epoch", y="BESTn", label="BESTn (Without Elitism)", color=color_no_elitism)
sns.lineplot(data=df_elitism, x="Epoch", y="BESTn", label="BESTn (With Elitism)", color=color_elitism)
plt.title(f"BESTn vs Generations (Target Length: {target_length}, Population: {population_size})")
plt.xlabel("Generations")
plt.ylabel("BESTn")
plt.legend()
plt.grid(True)
plt.show()
